# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew  
# %matplotlib inline

# %%
train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# dtype: int64

# %%
test.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage    227
# LotArea          0
# dtype: int64

# %%
# data is right skewed
train['SalePrice'].hist()

# %%
# After log the deviation seems to be normal 
np.log1p(train['SalePrice']).hist()

# %%
# get numeric and non numeric cols
numeric_cols = [ col for col in train.columns if train[col].dtype!="object" ]
categorical_cols = [col for col in train.columns if col not in numeric_cols]

# %%
bothdf = pd.concat([train,test],axis=0)

# %%
empty_df =  pd.DataFrame(bothdf.isnull().sum(),columns=['Empty Values'])
empty_df[empty_df['Empty Values']>1000]
# Out:
#              Empty Values
# Alley                2721
# Fence                2348
# FireplaceQu          1420
# MiscFeature          2814
# PoolQC               2909
# SalePrice            1459

# %%
bothdf = bothdf.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=1)
empty_df = empty_df.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=0)

# %%
empty_df = empty_df[empty_df['Empty Values']>0]
empty_df = empty_df.sort_values(ascending=False,by='Empty Values')
empty_df.head()
# Out:
#               Empty Values
# SalePrice             1459
# LotFrontage            486
# GarageYrBlt            159
# GarageQual             159
# GarageFinish           159

# %%
# get the highest correlation wrt LotFrontage
# seems like LotFrontage has high corr wrt LotArea,1stFlrSF,GrLivArea,GarageArea
corrdf = pd.DataFrame(bothdf.corr())
corrdf['LotFrontage'].sort_values(ascending=False).head()
# Out:
# LotFrontage    1.000000
# LotArea        0.489896
# 1stFlrSF       0.458247
# GrLivArea      0.382462
# GarageArea     0.359786
# Name: LotFrontage, dtype: float64

# %%
# preparing internal ML model to get lotfrontage missing values
bothdf[bothdf['LotFrontage'].notnull()].head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1   ...   SaleType  ScreenPorch  Street  \
# 0       706.0         0.0          GLQ   ...         WD            0    Pave
# 1       978.0         0.0          ALQ   ...         WD            0    Pave
# 2       486.0         0.0          GLQ   ...         WD            0    Pave
# 3       216.0         0.0          ALQ   ...         WD            0    Pave
# 4       655.0         0.0          GLQ   ...         WD            0    Pave
#
#   TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0            8        856.0    AllPub          0      2003         2003
# 1            6       1262.0    AllPub        298      1976         1976
# 2            6        920.0    AllPub          0      2001         2002
# 3            7        756.0    AllPub          0      1915         1970
# 4            9       1145.0    AllPub        192      2000         2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
#
# [5 rows x 76 columns]

# %%
# preparing the dataframe for processing
lotFr = bothdf[['LotArea','1stFlrSF','GrLivArea','GarageArea','LotFrontage']]
lotFr_nn = lotFr[lotFr['LotFrontage'].notnull() & lotFr['GarageArea'].notnull()]
lotFr.count()
lotFr_nn.isnull().sum()
# Out:
# LotArea        0
# 1stFlrSF       0
# GrLivArea      0
# GarageArea     0
# LotFrontage    0
# dtype: int64

# %%
X_lot = lotFr_nn.iloc[:, :-1].values
y_lot = lotFr_nn.iloc[:, 4:].values
y_lot
# Out:
# array([[  65.],
#        [  80.],
#        [  68.],
#        ...,
#        [ 160.],
#        [  62.],
#        [  74.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_lot, y_lot, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_lotfr_X = StandardScaler()
sc_lotfr_Y = StandardScaler()

X_lot_train = sc_lotfr_X.fit_transform(X_train)
X_lot_test = sc_lotfr_X.transform(X_test)

y_lot_train = sc_lotfr_Y.fit_transform(y_train)
y_lot_test = sc_lotfr_Y.transform(y_test)
y_lot_test
# Out:
# array([[ 3.12745773],
#        [-0.40620463],
#        [ 0.14067169],
#        [-1.6682269 ],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [ 0.43514355],
#        [ 1.40269396],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.78481131],
#        [ 1.40269396],
#        [ 2.11783991],
#        [-0.40620463],
#        [ 0.60341319],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.15380018],
#        [ 3.37986218],
#        [ 0.2248065 ],
#        [-0.61654168],
#        [-0.02759795],
#        [-0.19586759],
#        [-1.92063136],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.43514355],
#        [-1.16341799],
#        [-0.82687872],
#        [ 0.35100873],
#        [-0.06966536],
#        [ 0.14067169],
#        [-1.2054854 ],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.39307614],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.61654168],
#        [-0.86894613],
#        [ 0.18273909],
#        [ 0.01446946],
#        [-0.06966536],
#        [-0.02759795],
#        [-0.32206981],
#        [ 0.43514355],
#        [-0.82687872],
#        [-1.12135059],
#        [ 0.2248065 ],
#        [-0.7427439 ],
#        [-0.82687872],
#        [-0.82687872],
#        [ 0.64548059],
#        [-0.7427439 ],
#        [-0.11173277],
#        [ 0.01446946],
#        [-1.92063136],
#        [ 0.43514355],
#        [ 0.43514355],
#        [-1.45788986],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.09860428],
#        [-0.11173277],
#        [-1.07928318],
#        [ 0.64548059],
#        [-1.24755281],
#        [ 0.35100873],
#        [ 1.06615468],
#        [-0.40620463],
#        [-0.2800024 ],
#        [-2.04683358],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.36413722],
#        [-0.53240686],
#        [-0.95308095],
#        [-1.12135059],
#        [-0.7006765 ],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 2.95918809],
#        [-0.19586759],
#        [-0.11173277],
#        [ 0.18273909],
#        [ 0.64548059],
#        [-0.15380018],
#        [-0.19586759],
#        [-1.07928318],
#        [ 1.19235691],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.11173277],
#        [-1.2054854 ],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.19586759],
#        [ 0.43514355],
#        [-0.237935  ],
#        [-0.40620463],
#        [-0.15380018],
#        [ 0.2248065 ],
#        [ 0.30894132],
#        [-0.19586759],
#        [ 1.06615468],
#        [ 0.43514355],
#        [ 0.64548059],
#        [-0.32206981],
#        [-0.2800024 ],
#        [ 0.43514355],
#        [ 1.57096359],
#        [ 0.35100873],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.89788505],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.77168282],
#        [ 0.60341319],
#        [ 0.05653687],
#        [ 0.14067169],
#        [-0.40620463],
#        [-0.32206981],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [-1.58409209],
#        [ 0.64548059],
#        [-0.19586759],
#        [ 0.64548059],
#        [-1.92063136],
#        [ 1.69716582],
#        [-2.04683358],
#        [-0.15380018],
#        [-0.40620463],
#        [-0.02759795],
#        [ 1.06615468],
#        [-0.15380018],
#        [-0.19586759],
#        [ 1.19235691],
#        [ 1.69716582],
#        [-0.53240686],
#        [ 0.39307614],
#        [-1.2054854 ],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.78481131],
#        [ 3.463997  ],
#        [-0.7006765 ],
#        [-0.49033945],
#        [ 0.72961541],
#        [ 1.86543546],
#        [-1.24755281],
#        [-1.24755281],
#        [-0.61654168],
#        [-2.04683358],
#        [-0.40620463],
#        [ 0.85581764],
#        [-0.53240686],
#        [-0.95308095],
#        [-0.65860909],
#        [ 1.19235691],
#        [ 0.43514355],
#        [-0.82687872],
#        [-0.53240686],
#        [ 0.77168282],
#        [ 0.77168282],
#        [ 2.32817696],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [-1.6682269 ],
#        [-1.92063136],
#        [ 1.06615468],
#        [ 0.01446946],
#        [-2.04683358],
#        [ 0.43514355],
#        [ 2.49644659],
#        [-0.40620463],
#        [ 1.44476137],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.01446946],
#        [ 0.43514355],
#        [ 0.39307614],
#        [ 0.01446946],
#        [ 2.70678364],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.11173277],
#        [ 0.56134578],
#        [-0.40620463],
#        [ 0.64548059],
#        [-1.58409209],
#        [ 2.11783991],
#        [ 0.09860428],
#        [-0.2800024 ],
#        [-0.82687872],
#        [-0.7427439 ],
#        [ 0.64548059],
#        [ 0.01446946],
#        [-0.7006765 ],
#        [-0.61654168],
#        [-0.82687872],
#        [-1.37375504],
#        [-2.04683358],
#        [ 0.26687391],
#        [-0.40620463],
#        [-1.2054854 ],
#        [-0.06966536],
#        [-0.15380018],
#        [-1.54202468],
#        [-0.237935  ],
#        [ 0.01446946],
#        [-0.49033945],
#        [-0.82687872],
#        [-0.40620463],
#        [ 0.14067169],
#        [ 0.2248065 ],
#        [ 0.64548059],
#        [-0.57447427],
#        [ 0.93995246],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-1.49995727],
#        [ 1.27649173],
#        [ 0.09860428],
#        [ 0.43514355],
#        [ 0.39307614],
#        [-0.7006765 ],
#        [ 1.02408728],
#        [ 0.39307614],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [-1.28962022],
#        [-0.40620463],
#        [-0.82687872],
#        [-0.44827204],
#        [-0.2800024 ],
#        [-1.37375504],
#        [ 0.60341319],
#        [-0.40620463],
#        [-0.40620463],
#        [-1.49995727],
#        [-0.82687872],
#        [-0.82687872],
#        [-2.04683358],
#        [-0.237935  ],
#        [-0.19586759],
#        [-0.36413722],
#        [ 2.03370509],
#        [-2.04683358],
#        [-1.45788986],
#        [ 0.98201987],
#        [ 0.93995246],
#        [ 0.687548  ],
#        [ 0.98201987],
#        [-0.2800024 ],
#        [ 1.86543546],
#        [-0.49033945],
#        [-0.40620463],
#        [ 0.01446946],
#        [-2.04683358],
#        [-0.78481131],
#        [ 0.98201987],
#        [ 0.01446946],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [-0.44827204],
#        [ 0.51927837],
#        [-1.92063136],
#        [-0.40620463],
#        [-2.04683358],
#        [ 0.43514355],
#        [-0.19586759],
#        [ 0.47721096],
#        [ 2.28610955],
#        [-1.92063136],
#        [-2.04683358],
#        [-1.2054854 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 1.10822209],
#        [ 0.01446946],
#        [-1.24755281],
#        [-1.92063136],
#        [-1.92063136],
#        [-0.2800024 ],
#        [-0.02759795],
#        [ 0.64548059],
#        [ 0.85581764],
#        [-0.237935  ],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.53240686],
#        [-0.11173277],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [-0.40620463],
#        [ 0.35100873],
#        [ 1.02408728],
#        [-0.19586759],
#        [ 0.14067169],
#        [ 0.05653687],
#        [-0.7427439 ],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.43514355],
#        [-0.36413722],
#        [-0.19586759],
#        [-0.15380018],
#        [ 0.64548059],
#        [-0.82687872],
#        [-0.19586759],
#        [ 0.47721096],
#        [-0.82687872],
#        [-0.61654168],
#        [ 0.14067169],
#        [ 1.36062655],
#        [-0.44827204],
#        [-0.40620463],
#        [-1.92063136],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [-1.16341799],
#        [-1.58409209],
#        [-0.19586759],
#        [ 0.60341319],
#        [ 0.09860428],
#        [ 1.19235691],
#        [-0.06966536],
#        [-0.19586759],
#        [-0.40620463],
#        [ 0.05653687],
#        [ 0.35100873],
#        [ 0.81375023],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.687548  ],
#        [-0.82687872],
#        [-0.40620463],
#        [-0.06966536],
#        [-0.36413722],
#        [ 1.613031  ],
#        [ 0.64548059],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.237935  ],
#        [-0.19586759],
#        [ 0.51927837],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 1.65509841],
#        [ 0.05653687],
#        [ 0.687548  ],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [-0.40620463],
#        [-1.28962022],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 0.01446946],
#        [-0.40620463],
#        [ 0.39307614],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.43514355],
#        [-0.61654168],
#        [-0.19586759],
#        [-0.40620463],
#        [-1.07928318],
#        [-0.61654168],
#        [ 0.43514355],
#        [-0.78481131],
#        [-0.49033945],
#        [-1.41582245],
#        [-0.237935  ],
#        [ 0.85581764],
#        [-0.82687872],
#        [-0.78481131],
#        [ 3.59019923],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.43514355],
#        [-0.02759795],
#        [-1.45788986],
#        [-0.86894613],
#        [-0.65860909],
#        [ 0.2248065 ],
#        [ 1.06615468],
#        [ 0.14067169],
#        [ 0.60341319],
#        [-0.06966536],
#        [-0.2800024 ],
#        [-0.06966536],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.06966536],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 1.27649173],
#        [ 0.30894132],
#        [-0.02759795],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.14067169],
#        [-1.54202468],
#        [ 0.89788505],
#        [-1.58409209],
#        [-0.40620463],
#        [ 0.26687391],
#        [ 0.01446946],
#        [ 0.39307614],
#        [ 0.47721096],
#        [-0.40620463],
#        [ 0.18273909],
#        [ 0.85581764],
#        [-1.92063136],
#        [-0.19586759],
#        [-1.16341799],
#        [ 0.72961541],
#        [-0.19586759],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 2.49644659],
#        [ 0.43514355],
#        [-0.82687872],
#        [ 0.51927837],
#        [ 1.69716582],
#        [-0.49033945],
#        [ 1.78130064],
#        [-0.44827204],
#        [ 1.78130064],
#        [ 0.60341319],
#        [-1.92063136],
#        [-0.82687872],
#        [-0.11173277],
#        [ 0.93995246],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.98201987],
#        [ 0.09860428],
#        [-1.87856395],
#        [-0.02759795],
#        [-0.7427439 ],
#        [-1.45788986],
#        [ 0.60341319],
#        [-0.53240686],
#        [-0.57447427],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [ 1.19235691],
#        [ 0.01446946],
#        [ 0.18273909]])

# %%
from sklearn.ensemble import RandomForestRegressor
lot_reg = RandomForestRegressor()
lot_reg.fit(X_lot_train,y_lot_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
fr_preds = lot_reg.predict(X_lot_test)
fr_preds
# Out:
# array([  8.01130008e-01,  -4.81925968e-01,   6.66514299e-01,
#         -1.45368312e+00,   3.12964221e-02,   1.32258204e-01,
#          3.55031630e-02,   3.55031630e-02,   4.18316585e-01,
#          1.56675685e+00,   1.58779056e+00,  -3.01036109e-01,
#          1.04932772e+00,  -7.17503459e-01,   6.20240149e-01,
#         -3.47310259e-01,  -2.96829369e-01,  -1.74833882e-01,
#         -3.30483296e-01,  -1.45386696e-01,  -3.47310259e-01,
#          2.22721517e+00,   1.87805568e+00,  -1.03319287e-01,
#         -7.13296718e-01,  -4.02181733e-02,  -1.39478874e+00,
#         -1.92063136e+00,  -2.33912097e-02,   5.10864885e-01,
#         -7.80788415e-02,  -7.80604573e-01,   6.70721040e-01,
#         -2.16901291e-01,   2.70896811e-02,   2.20197473e+00,
#          1.07017758e-01,   1.28051463e-01,   1.57498649e-01,
#          8.17773129e-02,  -1.04142251e+00,   6.37067112e-01,
#         -5.28383960e-02,  -2.75979506e-02,  -7.80788415e-02,
#         -5.78681009e-01,   3.04734581e-01,   1.84923572e-03,
#         -2.08487810e-01,   1.84923572e-03,  -1.83247364e-01,
#          1.44878426e-01,   9.86042765e-02,   6.07619926e-01,
#          3.12964221e-02,  -7.38721006e-02,   5.10864885e-01,
#         -3.38896778e-01,   1.22601084e+00,  -3.72550705e-01,
#         -1.12555733e+00,   3.25768285e-01,  -7.63777609e-01,
#         -4.31445077e-01,  -5.45027082e-01,   1.86761993e-02,
#         -4.73512487e-01,   1.65912131e-01,  -3.47310259e-01,
#         -1.92063136e+00,   2.83700876e-01,  -1.79040623e-01,
#         -1.11714384e+00,   4.22523326e-01,  -1.49777279e-02,
#          2.70896811e-02,   4.26730067e-01,  -3.01036109e-01,
#          7.50649117e-01,  -1.07928318e+00,   8.89471567e-01,
#         -2.21108032e-01,   5.69759258e-01,   7.96923267e-01,
#         -3.38896778e-01,  -2.29521514e-01,  -2.04683358e+00,
#          2.37426726e-01,  -2.29521514e-01,  -2.21108032e-01,
#         -1.03319287e-01,  -9.32047245e-01,  -1.13397081e+00,
#         -1.24352991e-01,  -1.30644719e+00,   9.02091789e-01,
#          7.75889562e-01,   6.66514299e-01,  -4.18824855e-01,
