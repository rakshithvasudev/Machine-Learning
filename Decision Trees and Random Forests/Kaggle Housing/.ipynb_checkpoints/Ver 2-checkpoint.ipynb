# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew  
# %matplotlib inline

# %%
train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# dtype: int64

# %%
test.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage    227
# LotArea          0
# dtype: int64

# %%
# data is right skewed
train['SalePrice'].hist()

# %%
# After log the deviation seems to be normal 
np.log1p(train['SalePrice']).hist()

# %%
# get numeric and non numeric cols
numeric_cols = [ col for col in train.columns if train[col].dtype!="object" ]
categorical_cols = [col for col in train.columns if col not in numeric_cols]

# %%
bothdf = pd.concat([train,test],axis=0)

# %%
empty_df =  pd.DataFrame(bothdf.isnull().sum(),columns=['Empty Values'])
empty_df[empty_df['Empty Values']>1000]
# Out:
#              Empty Values
# Alley                2721
# Fence                2348
# FireplaceQu          1420
# MiscFeature          2814
# PoolQC               2909
# SalePrice            1459

# %%
bothdf = bothdf.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=1)
empty_df = empty_df.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=0)

# %%
empty_df = empty_df[empty_df['Empty Values']>0]
empty_df = empty_df.sort_values(ascending=False,by='Empty Values')
empty_df.head()
# Out:
#               Empty Values
# SalePrice             1459
# LotFrontage            486
# GarageYrBlt            159
# GarageQual             159
# GarageFinish           159

# %%
# get the highest correlation wrt LotFrontage
# seems like LotFrontage has high corr wrt LotArea,1stFlrSF,GrLivArea,GarageArea
corrdf = pd.DataFrame(bothdf.corr())
corrdf['LotFrontage'].sort_values(ascending=False).head()
# Out:
# LotFrontage    1.000000
# LotArea        0.489896
# 1stFlrSF       0.458247
# GrLivArea      0.382462
# GarageArea     0.359786
# Name: LotFrontage, dtype: float64

# %%
# preparing internal ML model to get lotfrontage missing values
bothdf[bothdf['LotFrontage'].notnull()].head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1   ...   SaleType  ScreenPorch  Street  \
# 0       706.0         0.0          GLQ   ...         WD            0    Pave
# 1       978.0         0.0          ALQ   ...         WD            0    Pave
# 2       486.0         0.0          GLQ   ...         WD            0    Pave
# 3       216.0         0.0          ALQ   ...         WD            0    Pave
# 4       655.0         0.0          GLQ   ...         WD            0    Pave
#
#   TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0            8        856.0    AllPub          0      2003         2003
# 1            6       1262.0    AllPub        298      1976         1976
# 2            6        920.0    AllPub          0      2001         2002
# 3            7        756.0    AllPub          0      1915         1970
# 4            9       1145.0    AllPub        192      2000         2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
#
# [5 rows x 76 columns]

# %%
# preparing the dataframe for processing
lotFr = bothdf[['LotArea','1stFlrSF','GrLivArea','GarageArea','LotFrontage']]
lotFr_nn = lotFr[lotFr['LotFrontage'].notnull() & lotFr['GarageArea'].notnull()]
lotFr.count()
lotFr_nn.isnull().sum()
# Out:
# LotArea        0
# 1stFlrSF       0
# GrLivArea      0
# GarageArea     0
# LotFrontage    0
# dtype: int64

# %%
X_lot = lotFr_nn.iloc[:, :-1].values
y_lot = lotFr_nn.iloc[:, 4:].values
y_lot
# Out:
# array([[  65.],
#        [  80.],
#        [  68.],
#        ...,
#        [ 160.],
#        [  62.],
#        [  74.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_lot, y_lot, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_lotfr_X = StandardScaler()
sc_lotfr_Y = StandardScaler()

X_lot_train = sc_lotfr_X.fit_transform(X_train)
X_lot_test = sc_lotfr_X.transform(X_test)

y_lot_train = sc_lotfr_Y.fit_transform(y_train)
y_lot_test = sc_lotfr_Y.transform(y_test)
y_lot_test
# Out:
# array([[ 3.12745773],
#        [-0.40620463],
#        [ 0.14067169],
#        [-1.6682269 ],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [ 0.43514355],
#        [ 1.40269396],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.78481131],
#        [ 1.40269396],
#        [ 2.11783991],
#        [-0.40620463],
#        [ 0.60341319],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.15380018],
#        [ 3.37986218],
#        [ 0.2248065 ],
#        [-0.61654168],
#        [-0.02759795],
#        [-0.19586759],
#        [-1.92063136],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.43514355],
#        [-1.16341799],
#        [-0.82687872],
#        [ 0.35100873],
#        [-0.06966536],
#        [ 0.14067169],
#        [-1.2054854 ],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.39307614],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.61654168],
#        [-0.86894613],
#        [ 0.18273909],
#        [ 0.01446946],
#        [-0.06966536],
#        [-0.02759795],
#        [-0.32206981],
#        [ 0.43514355],
#        [-0.82687872],
#        [-1.12135059],
#        [ 0.2248065 ],
#        [-0.7427439 ],
#        [-0.82687872],
#        [-0.82687872],
#        [ 0.64548059],
#        [-0.7427439 ],
#        [-0.11173277],
#        [ 0.01446946],
#        [-1.92063136],
#        [ 0.43514355],
#        [ 0.43514355],
#        [-1.45788986],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.09860428],
#        [-0.11173277],
#        [-1.07928318],
#        [ 0.64548059],
#        [-1.24755281],
#        [ 0.35100873],
#        [ 1.06615468],
#        [-0.40620463],
#        [-0.2800024 ],
#        [-2.04683358],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.36413722],
#        [-0.53240686],
#        [-0.95308095],
#        [-1.12135059],
#        [-0.7006765 ],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 2.95918809],
#        [-0.19586759],
#        [-0.11173277],
#        [ 0.18273909],
#        [ 0.64548059],
#        [-0.15380018],
#        [-0.19586759],
#        [-1.07928318],
#        [ 1.19235691],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.11173277],
#        [-1.2054854 ],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.19586759],
#        [ 0.43514355],
#        [-0.237935  ],
#        [-0.40620463],
#        [-0.15380018],
#        [ 0.2248065 ],
#        [ 0.30894132],
#        [-0.19586759],
#        [ 1.06615468],
#        [ 0.43514355],
#        [ 0.64548059],
#        [-0.32206981],
#        [-0.2800024 ],
#        [ 0.43514355],
#        [ 1.57096359],
#        [ 0.35100873],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.89788505],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.77168282],
#        [ 0.60341319],
#        [ 0.05653687],
#        [ 0.14067169],
#        [-0.40620463],
#        [-0.32206981],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [-1.58409209],
#        [ 0.64548059],
#        [-0.19586759],
#        [ 0.64548059],
#        [-1.92063136],
#        [ 1.69716582],
#        [-2.04683358],
#        [-0.15380018],
#        [-0.40620463],
#        [-0.02759795],
#        [ 1.06615468],
#        [-0.15380018],
#        [-0.19586759],
#        [ 1.19235691],
#        [ 1.69716582],
#        [-0.53240686],
#        [ 0.39307614],
#        [-1.2054854 ],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.78481131],
#        [ 3.463997  ],
#        [-0.7006765 ],
#        [-0.49033945],
#        [ 0.72961541],
#        [ 1.86543546],
#        [-1.24755281],
#        [-1.24755281],
#        [-0.61654168],
#        [-2.04683358],
#        [-0.40620463],
#        [ 0.85581764],
#        [-0.53240686],
#        [-0.95308095],
#        [-0.65860909],
#        [ 1.19235691],
#        [ 0.43514355],
#        [-0.82687872],
#        [-0.53240686],
#        [ 0.77168282],
#        [ 0.77168282],
#        [ 2.32817696],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [-1.6682269 ],
#        [-1.92063136],
#        [ 1.06615468],
#        [ 0.01446946],
#        [-2.04683358],
#        [ 0.43514355],
#        [ 2.49644659],
#        [-0.40620463],
#        [ 1.44476137],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.01446946],
#        [ 0.43514355],
#        [ 0.39307614],
#        [ 0.01446946],
#        [ 2.70678364],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.11173277],
#        [ 0.56134578],
#        [-0.40620463],
#        [ 0.64548059],
#        [-1.58409209],
#        [ 2.11783991],
#        [ 0.09860428],
#        [-0.2800024 ],
#        [-0.82687872],
#        [-0.7427439 ],
#        [ 0.64548059],
#        [ 0.01446946],
#        [-0.7006765 ],
#        [-0.61654168],
#        [-0.82687872],
#        [-1.37375504],
#        [-2.04683358],
#        [ 0.26687391],
#        [-0.40620463],
#        [-1.2054854 ],
#        [-0.06966536],
#        [-0.15380018],
#        [-1.54202468],
#        [-0.237935  ],
#        [ 0.01446946],
#        [-0.49033945],
#        [-0.82687872],
#        [-0.40620463],
#        [ 0.14067169],
#        [ 0.2248065 ],
#        [ 0.64548059],
#        [-0.57447427],
#        [ 0.93995246],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-1.49995727],
#        [ 1.27649173],
#        [ 0.09860428],
#        [ 0.43514355],
#        [ 0.39307614],
#        [-0.7006765 ],
#        [ 1.02408728],
#        [ 0.39307614],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [-1.28962022],
#        [-0.40620463],
#        [-0.82687872],
#        [-0.44827204],
#        [-0.2800024 ],
#        [-1.37375504],
#        [ 0.60341319],
#        [-0.40620463],
#        [-0.40620463],
#        [-1.49995727],
#        [-0.82687872],
#        [-0.82687872],
#        [-2.04683358],
#        [-0.237935  ],
#        [-0.19586759],
#        [-0.36413722],
#        [ 2.03370509],
#        [-2.04683358],
#        [-1.45788986],
#        [ 0.98201987],
#        [ 0.93995246],
#        [ 0.687548  ],
#        [ 0.98201987],
#        [-0.2800024 ],
#        [ 1.86543546],
#        [-0.49033945],
#        [-0.40620463],
#        [ 0.01446946],
#        [-2.04683358],
#        [-0.78481131],
#        [ 0.98201987],
#        [ 0.01446946],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [-0.44827204],
#        [ 0.51927837],
#        [-1.92063136],
#        [-0.40620463],
#        [-2.04683358],
#        [ 0.43514355],
#        [-0.19586759],
#        [ 0.47721096],
#        [ 2.28610955],
#        [-1.92063136],
#        [-2.04683358],
#        [-1.2054854 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 1.10822209],
#        [ 0.01446946],
#        [-1.24755281],
#        [-1.92063136],
#        [-1.92063136],
#        [-0.2800024 ],
#        [-0.02759795],
#        [ 0.64548059],
#        [ 0.85581764],
#        [-0.237935  ],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.53240686],
#        [-0.11173277],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [-0.40620463],
#        [ 0.35100873],
#        [ 1.02408728],
#        [-0.19586759],
#        [ 0.14067169],
#        [ 0.05653687],
#        [-0.7427439 ],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.43514355],
#        [-0.36413722],
#        [-0.19586759],
#        [-0.15380018],
#        [ 0.64548059],
#        [-0.82687872],
#        [-0.19586759],
#        [ 0.47721096],
#        [-0.82687872],
#        [-0.61654168],
#        [ 0.14067169],
#        [ 1.36062655],
#        [-0.44827204],
#        [-0.40620463],
#        [-1.92063136],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [-1.16341799],
#        [-1.58409209],
#        [-0.19586759],
#        [ 0.60341319],
#        [ 0.09860428],
#        [ 1.19235691],
#        [-0.06966536],
#        [-0.19586759],
#        [-0.40620463],
#        [ 0.05653687],
#        [ 0.35100873],
#        [ 0.81375023],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.687548  ],
#        [-0.82687872],
#        [-0.40620463],
#        [-0.06966536],
#        [-0.36413722],
#        [ 1.613031  ],
#        [ 0.64548059],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.237935  ],
#        [-0.19586759],
#        [ 0.51927837],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 1.65509841],
#        [ 0.05653687],
#        [ 0.687548  ],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [-0.40620463],
#        [-1.28962022],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 0.01446946],
#        [-0.40620463],
#        [ 0.39307614],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.43514355],
#        [-0.61654168],
#        [-0.19586759],
#        [-0.40620463],
#        [-1.07928318],
#        [-0.61654168],
#        [ 0.43514355],
#        [-0.78481131],
#        [-0.49033945],
#        [-1.41582245],
#        [-0.237935  ],
#        [ 0.85581764],
#        [-0.82687872],
#        [-0.78481131],
#        [ 3.59019923],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.43514355],
#        [-0.02759795],
#        [-1.45788986],
#        [-0.86894613],
#        [-0.65860909],
#        [ 0.2248065 ],
#        [ 1.06615468],
#        [ 0.14067169],
#        [ 0.60341319],
#        [-0.06966536],
#        [-0.2800024 ],
#        [-0.06966536],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.06966536],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 1.27649173],
#        [ 0.30894132],
#        [-0.02759795],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.14067169],
#        [-1.54202468],
#        [ 0.89788505],
#        [-1.58409209],
#        [-0.40620463],
#        [ 0.26687391],
#        [ 0.01446946],
#        [ 0.39307614],
#        [ 0.47721096],
#        [-0.40620463],
#        [ 0.18273909],
#        [ 0.85581764],
#        [-1.92063136],
#        [-0.19586759],
#        [-1.16341799],
#        [ 0.72961541],
#        [-0.19586759],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 2.49644659],
#        [ 0.43514355],
#        [-0.82687872],
#        [ 0.51927837],
#        [ 1.69716582],
#        [-0.49033945],
#        [ 1.78130064],
#        [-0.44827204],
#        [ 1.78130064],
#        [ 0.60341319],
#        [-1.92063136],
#        [-0.82687872],
#        [-0.11173277],
#        [ 0.93995246],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.98201987],
#        [ 0.09860428],
#        [-1.87856395],
#        [-0.02759795],
#        [-0.7427439 ],
#        [-1.45788986],
#        [ 0.60341319],
#        [-0.53240686],
#        [-0.57447427],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [ 1.19235691],
#        [ 0.01446946],
#        [ 0.18273909]])

# %%
from sklearn.svm import SVR
lot_reg = SVR()
lot_reg.fit(X_lot_train,y_lot_train.ravel())
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
fr_preds = lot_reg.predict(X_lot_test)
fr_preds
# Out:
# array([  7.22285028e-01,  -5.79343397e-04,   5.83756802e-01,
#         -1.70060093e+00,   1.36968606e-01,  -3.49798108e-01,
#          2.29162883e-01,   4.55475504e-02,   2.04651709e-01,
#          1.41860087e+00,   1.64274488e+00,  -1.77694273e-01,
#          9.22379917e-01,  -7.36384125e-01,   8.62122437e-01,
#          8.75057834e-01,  -5.14633942e-01,  -2.73936405e-01,
#         -1.99703387e-01,  -1.81537771e-01,  -2.59301286e-02,
#          1.00292550e+00,   1.00846001e+00,   2.39869159e-01,
#         -1.06133239e+00,   7.69891164e-02,  -5.76334294e-01,
#         -1.84818952e+00,  -6.84160054e-02,   7.34522010e-01,
#          3.33075403e-02,  -7.71726773e-01,   2.46263065e-01,
#         -6.44921422e-01,   1.97039676e-02,   1.23654628e+00,
#         -3.45483739e-01,   9.94879061e-02,   1.00506154e-01,
#         -4.42295590e-03,  -7.94325756e-01,   2.34107312e-01,
#         -1.36430938e-01,  -4.81312680e-02,  -1.26830481e-02,
#         -2.02104291e-01,   2.95947302e-01,   2.31022198e-02,
#         -4.04669780e-01,   4.09183881e-01,   1.34233035e-01,
#          7.11723724e-01,  -3.60549007e-01,   3.12782414e-01,
#          2.72518778e-01,  -2.12846468e-01,   6.19781075e-01,
#         -2.15194022e-01,   5.22032184e-01,  -8.16274394e-01,
#         -1.45902302e+00,   3.53979874e-01,  -6.44606968e-01,
#         -5.79873330e-01,  -5.30190369e-01,  -4.42067802e-02,
#         -6.83202089e-01,   3.21178857e-01,  -1.37028402e-01,
#         -1.85682565e+00,   2.36889491e-01,   9.37239364e-01,
#         -1.27071632e+00,   3.71380718e-01,  -1.14305282e-01,
#          5.69835849e-02,   3.74799052e-01,  -3.14106076e-01,
#         -2.87940048e-01,  -1.18729972e+00,   1.15571658e+00,
#         -6.89217996e-01,   3.72209327e-01,   7.08931282e-01,
#         -2.70201618e-01,  -3.32194627e-01,  -1.90101622e+00,
#          3.21191628e-01,  -2.52254071e-01,  -1.49733793e-02,
#         -1.55183491e-02,  -1.05627436e+00,  -1.27563287e+00,
#         -6.76805693e-02,  -1.13516596e+00,   9.21512430e-01,
#          4.58111729e-01,   4.30652968e-01,  -3.13054963e-01,
#         -2.24589714e-01,   2.41385790e-01,  -4.26350440e-01,
#         -2.82003472e-01,  -4.77190493e-01,   9.03181405e-01,
#          4.29237396e-01,  -1.51237681e-01,  -1.80856308e-01,
#         -1.59081001e+00,  -2.06002799e-01,  -1.93691759e-01,
#          1.83437859e-04,   1.75055835e-01,  -1.26251502e-01,
#         -4.69152530e-01,   5.90261924e-01,   4.86278135e-01,
#         -1.71412233e-01,  -8.96572143e-02,   5.47768860e-01,
#          3.08821134e-01,   1.15585699e-01,  -1.75110093e-01,
#         -1.96104672e-01,   1.04098558e-01,   1.26754787e+00,
#         -1.22042796e-01,   6.46381934e-02,  -2.72442903e-01,
#          6.56185563e-01,   8.56079838e-01,  -4.70883932e-01,
#          4.02549743e-01,   3.02492317e-01,   6.60996028e-01,
#         -8.87406017e-02,  -4.85321211e-01,   5.64092928e-01,
#          3.21216645e-01,   3.28639264e-01,   1.09146544e+00,
#         -8.82910094e-01,  -1.67067590e-01,   1.90266962e-01,
#         -1.26708170e-01,  -8.67579953e-01,   4.39754403e-01,
#         -1.63162256e-01,   5.75435675e-01,  -1.86221863e+00,
#          1.22011683e+00,  -1.97473741e+00,   5.90261924e-01,
#         -4.86276564e-01,  -7.06289391e-01,   1.02776486e+00,
#         -1.99887569e-01,  -5.88223789e-02,   8.04949058e-01,
#         -3.26745797e-01,  -4.64687934e-01,  -3.08336147e-01,
#         -7.27747382e-01,  -2.62377201e-01,  -1.45559259e-01,
#         -7.61718632e-01,  -1.36575647e+00,   4.03494157e-01,
#         -1.03716759e+00,   7.36811459e-01,   5.30199741e-01,
#          1.10512414e+00,  -8.83509176e-01,  -9.07617523e-01,
#          3.54506277e-03,  -1.97473741e+00,  -5.03044717e-01,
#          7.41787186e-01,  -6.03452171e-01,   8.95888788e-01,
#         -5.70353125e-01,   6.20103485e-01,  -1.43203025e-01,
#         -6.70098023e-01,  -3.82561912e-02,   6.80453351e-01,
#          1.27639427e-01,   1.34742869e+00,  -2.07380289e-01,
#          3.89066812e-02,  -1.24489900e+00,  -2.04469099e+00,
#          5.08790892e-01,  -3.57850370e-01,  -1.90511181e+00,
#          1.89338919e-01,   1.45725788e+00,  -6.71724706e-01,
#          1.13528253e+00,   5.83307865e-01,  -3.05578867e-01,
#          6.92856185e-01,  -1.39068275e-01,  -2.88861063e-01,
#         -1.56480540e-02,   1.02395983e+00,  -1.59913290e-01,
#         -4.64630206e-01,  -6.43510330e-01,  -8.79010903e-01,
#          2.69604084e-01,  -3.48759374e-01,   5.75018723e-01,
#         -1.30267690e+00,   1.90894773e-01,  -3.88641847e-01,
#         -8.73145120e-02,  -1.33576970e-01,  -4.18831824e-01,
#          9.37754358e-01,   3.98978556e-01,  -1.25976775e+00,
#         -2.53850507e-01,  -2.21091236e-01,  -1.43350203e+00,
#         -1.83845255e+00,   4.52505148e-01,   3.01038951e-01,
#          2.93571089e-01,  -6.16707260e-02,   1.36108867e+00,
#         -9.50192112e-01,  -2.29594383e-01,   6.04911425e-02,
#         -2.14142153e-01,  -7.61455528e-01,   4.82221890e-01,
#         -1.65194700e-01,   4.61200355e-01,   6.88648701e-01,
#          1.45400372e+00,  -6.05560061e-01,  -2.84203322e-01,
#          2.61818359e-02,  -8.44940970e-01,  -8.93808474e-01,
#          1.50802924e+00,   8.54098470e-02,   2.96937206e-01,
#         -2.65472095e-01,   1.20625423e+00,   9.67888084e-01,
#          1.35735980e+00,  -5.02007112e-01,  -7.09009197e-02,
#          2.84514235e-01,  -8.72432030e-01,  -1.89186050e-01,
#         -9.51764293e-01,  -1.46177432e-04,  -2.10065903e-01,
#         -2.05039974e-01,   6.10001714e-01,  -1.43911326e-01,
#         -2.83205697e-01,  -9.30853783e-01,   2.41672943e-01,
#         -3.43921589e-01,  -1.89231476e+00,   6.64706047e-02,
#         -3.89120348e-02,  -3.43049552e-01,   1.20126380e+00,
#         -1.97473741e+00,  -1.36646545e+00,   3.28660921e-01,
#          3.92315499e-01,   6.17355565e-01,   6.96841741e-01,
#          8.56838740e-01,  -1.74779478e-01,   7.75420551e-01,
#         -5.11615517e-01,  -5.28902013e-01,  -1.56514433e+00,
#         -6.67463360e-01,   8.49894408e-01,  -4.64693448e-03,
#         -7.21956100e-01,   2.34657301e-01,  -2.07303014e-01,
#         -1.77688512e-01,  -1.13488442e+00,   1.09625148e+00,
#         -1.51357443e+00,  -2.34110799e-01,  -1.93212614e+00,
#          1.09065911e-01,  -2.41581731e-01,   1.17525901e-01,
#          9.11099597e-01,  -2.06616543e+00,  -1.95727652e+00,
#          5.86230876e-01,  -1.12665902e-01,  -1.70090270e-02,
#          5.93047457e-01,  -2.84539063e-01,  -1.18189350e+00,
#         -1.74739344e+00,  -1.73562033e+00,   4.71663190e-01,
#         -3.93049242e-01,   3.03670017e-01,   2.48579451e-01,
#          1.11070615e-01,  -3.65847429e-01,   2.47719318e-01,
#          3.59550153e-01,  -3.10261463e-01,  -3.51252481e-01,
#         -4.24198710e-02,  -5.39680178e-02,  -6.89202158e-01,
#          2.14501672e-01,  -3.66486410e-01,  -1.78051797e-01,
#          1.48035981e-03,   1.08021855e+00,  -3.84074443e-01,
#          8.07983665e-01,   2.77630961e-01,  -1.03568782e+00,
#          7.03438193e-02,  -2.40468533e-02,   1.08729368e-01,
#          4.49605417e-01,  -4.42967666e-01,  -1.55621307e-01,
#          2.84791257e-01,  -1.30131130e-01,  -4.46237006e-01,
#         -5.21525180e-01,  -1.19183866e+00,  -1.32973758e-01,
#          1.48292953e-02,   1.09876281e+00,   3.48204323e-01,
#         -2.11806612e-01,  -2.16025965e+00,  -4.11550382e-01,
#          4.61859909e-01,  -1.15569524e+00,  -9.07338153e-01,
#         -2.67116460e-01,   2.52956001e-01,  -1.15013492e-01,
#         -4.72572672e-02,   9.83182444e-02,  -1.66374912e-02,
#         -3.52403860e-01,  -4.37024755e-02,   5.53964874e-01,
#          3.20945449e-01,   1.00088464e+00,   2.87043134e-02,
#         -1.77818196e-01,   6.97472282e-01,  -4.85022897e-01,
#          5.38159145e-01,  -2.86901885e-01,   3.70805821e-02,
#          1.50792943e+00,   1.49245167e+00,   9.74322766e-01,
#         -1.69951072e-01,  -2.51132934e-01,   5.46776359e-01,
#          5.11254118e-01,  -5.54627499e-02,  -2.13598397e-01,
#          3.69628586e-02,  -7.89571705e-01,  -4.32560480e-02,
#         -3.75565630e-01,   7.64552997e-01,   6.34647466e-01,
#          7.41919123e-02,   6.29549010e-01,  -2.46768074e-01,
#         -1.30052057e+00,  -1.73767720e+00,   3.61533507e-01,
#          2.76620587e-02,  -1.39865777e+00,   2.65062864e-01,
#          7.23535897e-01,   1.36030633e-01,   2.45687717e-01,
#         -6.57876821e-02,  -1.56665728e-01,  -2.50286747e-01,
#          3.81994179e-01,  -5.11735284e-01,   4.69932441e-01,
#         -2.92141666e-01,   1.74979482e-01,  -7.12967236e-01,
#          1.50027290e-01,   5.10150656e-01,  -3.09073291e-01,
#         -5.64548142e-01,   1.35491877e+00,  -1.39512941e-01,
#         -1.51602360e-01,   2.82798710e-01,  -1.50116544e-01,
#         -1.25114351e+00,   1.26541831e+00,  -5.61154261e-01,
#          1.72251722e-01,   6.35935240e-01,   3.29074670e-01,
#          2.15258889e-01,   1.80197703e-02,   7.11648274e-01,
#          1.21277924e-01,  -1.64551968e-01,   1.22325870e+00,
#         -1.17120296e+00,   2.41962321e-03,  -5.48121473e-01,
#          4.85850476e-01,   4.88259204e-01,  -9.96271742e-01,
#          1.92902968e-01,  -2.29867192e-01,  -4.39996155e-01,
#         -1.16097884e+00,   5.99958929e-01,  -1.12620202e+00,
#         -2.64617925e-01,   1.94019369e-01,  -6.23277099e-01,
#          2.66617872e-01,  -2.15666073e-01,  -4.05608124e-01,
#         -1.59076157e-01,   1.92200311e-01,  -1.51357443e+00,
#         -5.08380341e-02,   1.23239926e+00,   6.95067199e-01,
#         -3.31842269e-01,   8.36262235e-01,   5.86057074e-01,
#          1.76853286e-01,   5.96953804e-02,   3.08265191e-01,
#         -3.02607660e-01,   1.72851183e-04,   9.70870638e-01,
#         -6.54979795e-01,   1.08692208e+00,  -8.57858417e-01,
#          8.19928609e-01,  -2.38095844e-01,  -1.56120853e+00,
#         -5.73980508e-01,   1.39849642e+00,  -1.43711689e-01,
#          1.81797673e-02,   6.04867380e-01,   8.00648614e-01,
#          3.03885137e-01,  -9.54209575e-01,   1.71618208e-01,
#         -9.28422462e-01,  -1.35044242e+00,   3.74603083e-01,
#         -1.84644916e-01,   1.59259139e+00,  -1.02693536e-01,
#          2.24990379e-01,   7.40681867e-01,   1.15187425e+00,
#          7.25859198e-01])

# %%
from sklearn.model_selection import cross_val_score
cross_score = cross_val_score(lot_reg,X_lot_train,y_lot_train,cv=5,n_jobs=-1)
print(cross_score)
np.var(cross_score)
# Out:
# [ 0.53547098  0.35643152  0.55053043  0.5328163   0.3769226 ]
# 0.0072555495841991847

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_lot_test, fr_preds)))
# Out:
# RMSE: 0.636652355145

# %%
# without transforming
from sklearn.ensemble import RandomForestRegressor
rreg = RandomForestRegressor()
rreg.fit(X_train,y_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
new_preds = rreg.predict(X_test)
new_preds
# Out:
# array([  88.8,   60.5,   86.7,   31. ,   65.5,   62.6,   68.1,   75. ,
#          84.5,  103.6,  109.7,   60.3,   97.5,   53.3,   90.3,   92.8,
#          63. ,   66.7,   54.2,   63.9,   62.1,  114. ,  120.9,   66.9,
#          56.4,   67. ,   39.1,   24. ,   63.1,   85.3,   64.4,   52.2,
#          75.1,   65.3,   72.3,   90.9,   76.3,   81. ,   65.2,   71.8,
#          47.7,   80.5,   68. ,   72.6,   80. ,   55.6,   82.1,   68.7,
#          62.5,   71.2,   66. ,   73.9,   66.2,   77.9,   70.3,   57.3,
#          79.4,   60.1,   92.3,   61.6,   37.2,   82.5,   51.6,   57.9,
#          66.1,   72.2,   58.4,   83.2,   75.4,   24. ,   76.4,   84.7,
#          37.6,   71.3,   65.7,   64.8,   80.1,   48.9,   71.2,   44. ,
#          82.2,   61.5,   79.9,   90.2,   61.9,   62.4,   21. ,   81.7,
#          65.6,   71.9,   67.5,   60.7,   45.3,   61.3,   37. ,   85.9,
#          65.3,   85.4,   63.8,   70.7,   84.3,   59.4,   58.9,   41.6,
#          88.5,   75.2,   64.9,   81.9,   39.3,   65. ,   62.3,   66.4,
#          84.5,   72. ,   60. ,   59.6,   80.9,   76.2,   54.6,   84.8,
#          76.8,   77.3,   63. ,   66.3,   72.7,   97.9,   62.9,   78.6,
#          65.9,   97.1,  109.4,   59. ,   77.5,   79.2,   77.2,   65.7,
#          58.8,   89. ,   79.9,   72. ,   79.2,   87.9,   63.4,   67.6,
#          76.3,   37.4,   76.5,   64.2,   72.8,   24. ,  108.7,   21. ,
#          59.6,   63.2,   43.3,   88.9,   63.5,   65.5,   82. ,   66.7,
#          67. ,   61.7,   39.4,   64.2,   63. ,   55. ,   50.9,   61.7,
#          45.6,   91.9,   77.5,   98.5,   43.3,   59. ,   71.1,   21. ,
#          55. ,   78.7,   55.6,   64.6,   61.2,   84.3,   69.5,   50.8,
#          74.1,   97.3,   68.5,   87.5,   64.2,   70. ,   44.9,   23.7,
#          63.7,   59.8,   21. ,   79.8,   96. ,   62. ,   92.7,   76.3,
#          55.1,   90.3,   65.1,   55.9,   63.9,   84.8,   61.8,   55.5,
#          63. ,   65.6,   89.3,   62.5,   88.1,   52. ,   67.3,   62.7,
#          69.9,   75.4,   50.6,   91.9,   61.6,   52.3,   59.8,   65.4,
#          39.7,   23. ,   69.1,   85.6,   61.4,   67.2,  100. ,   48.9,
#          67.7,   68.5,   61.3,   51.1,   84.7,   66.9,   74.7,   83.4,
#          91.8,   52.9,   57.9,   73.2,   57.1,   35.1,  100.3,   70.8,
#          83.6,   77.6,   96.5,  108.7,  101.7,   56.6,   69.4,   78.2,
#          38. ,   66.9,   54.2,   64.6,   71.4,   69.4,   76.7,   66.4,
#          60. ,   35.8,   78. ,   55.4,   22. ,   81.2,   63.9,   53.5,
#         111.4,   21. ,   34.2,   81.4,   80.2,   78.9,   59.6,   92.3,
#          65.3,   87.9,   58.4,   57.5,   21. ,   54.5,   95.6,   68.2,
#          52.6,   75. ,   74.4,   66.8,   45.1,   92. ,   24. ,   55. ,
#          21. ,   74. ,   64.3,   66.1,   60.9,   23.4,   21. ,   76.4,
#          56.6,   73.4,   89.3,   72.5,   89.6,   24. ,   24. ,   89.6,
#          65.7,   81.1,   85.4,   75.3,   73.2,   75.2,   77.8,   49.1,
#          66.2,   69.1,   62.4,   55.5,   74.8,   72.2,   61.9,   73.2,
#         100.7,   59.6,   77.2,   73.3,   63.8,   77.7,   67.6,   70.7,
#          71.2,   58.4,   65.3,   78. ,   67.6,   64.5,   58.3,   26.4,
#          67.1,   67.9,   93.9,   65.8,   66.1,   23.4,   57.3,   75.9,
#          44.2,   34.1,   66.5,   80. ,   61. ,   71.9,   70.7,   58.1,
#          62.3,   63.8,   91. ,   74.3,  110.7,   77.2,   60.3,   94.4,
#          59.2,   90.7,   67.2,   66.2,   97.3,   94.6,   97.7,   65.3,
#          65.6,   73.5,   83.2,   71. ,   61.5,   61.7,   56. ,   97.6,
#          66. ,  106.5,   83. ,   69.7,  101.9,   60.1,   56.2,   25.1,
#          75.8,   59.7,   55.3,   63.5,  104.8,   69.8,   78.7,   81.7,
#          68.1,   64.9,   75.7,   56.4,   69.2,   62.5,   84.7,   49.1,
#          68.7,   67.6,   61.4,   63.5,  109.9,   74.5,   65.7,   61.9,
#          76.3,   42.1,  113.8,   59.1,   69.5,   91.1,   66.1,   71.5,
#          74.5,   72.4,   71.1,   65.1,   98. ,   55.4,   71. ,   59.6,
#          84.1,   83.7,   53.1,   61.7,   64. ,   64.6,   37.6,   81.9,
#          45.6,   74.7,   76.3,   57. ,   72.1,   62.8,   60. ,   66.8,
#          74.6,   24. ,   64.9,  105.7,   98.6,   66.4,   84.7,   58.9,
#          77.1,   74.8,   78.8,   49.8,   61.8,  107.2,   55.7,  101. ,
#          50.2,   94.2,   69. ,   28.8,   53.8,  106.3,   56. ,   70.1,
#          89.8,   96.8,   78.5,   41.6,   66.3,   59.6,   35. ,   76. ,
#          64.5,  129.6,   63.3,   87.9,   84.7,  120.8,   77.9])

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(new_preds, y_test)))
# Out:
# RMSE: 16.589294809

# %%
from sklearn.model_selection import cross_val_score
cross_score = cross_val_score(rreg,X_train,y_train,cv=5,n_jobs=-1)
print(cross_score)
print(np.mean(cross_score))
np.var(cross_score)
# Out:
# [ 0.56821969  0.35832196  0.45060879  0.50613484  0.38875043]
# 0.454407142972
# 0.0058373290365177181
