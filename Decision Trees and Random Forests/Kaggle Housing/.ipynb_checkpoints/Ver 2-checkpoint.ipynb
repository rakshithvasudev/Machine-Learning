# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew  
# %matplotlib inline

# %%
train = pd.read_csv("dataset/train.csv")
test = pd.read_csv("dataset/test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage    259
# LotArea          0
# dtype: int64

# %%
test.isnull().sum().head()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage    227
# LotArea          0
# dtype: int64

# %%
# data is right skewed
train['SalePrice'].hist()

# %%
# After log the deviation seems to be normal 
np.log1p(train['SalePrice']).hist()

# %%
# get numeric and non numeric cols
numeric_cols = [ col for col in train.columns if train[col].dtype!="object" ]
categorical_cols = [col for col in train.columns if col not in numeric_cols]

# %%
bothdf = pd.concat([train,test],axis=0)

# %%
empty_df =  pd.DataFrame(bothdf.isnull().sum(),columns=['Empty Values'])
empty_df[empty_df['Empty Values']>1000]
# Out:
#              Empty Values
# Alley                2721
# Fence                2348
# FireplaceQu          1420
# MiscFeature          2814
# PoolQC               2909
# SalePrice            1459

# %%
bothdf = bothdf.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=1)
empty_df = empty_df.drop(['Alley','Fence','FireplaceQu','MiscFeature','PoolQC'],axis=0)

# %%
empty_df = empty_df[empty_df['Empty Values']>0]
empty_df = empty_df.sort_values(ascending=False,by='Empty Values')
empty_df.head()
# Out:
#               Empty Values
# SalePrice             1459
# LotFrontage            486
# GarageYrBlt            159
# GarageQual             159
# GarageFinish           159

# %%
# get the highest correlation wrt LotFrontage
# seems like LotFrontage has high corr wrt LotArea,1stFlrSF,GrLivArea,GarageArea
corrdf = pd.DataFrame(bothdf.corr())
corrdf['LotFrontage'].sort_values(ascending=False).head()
# Out:
# LotFrontage    1.000000
# LotArea        0.489896
# 1stFlrSF       0.458247
# GrLivArea      0.382462
# GarageArea     0.359786
# Name: LotFrontage, dtype: float64

# %%
# preparing internal ML model to get lotfrontage missing values
bothdf[bothdf['LotFrontage'].notnull()].head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1   ...   SaleType  ScreenPorch  Street  \
# 0       706.0         0.0          GLQ   ...         WD            0    Pave
# 1       978.0         0.0          ALQ   ...         WD            0    Pave
# 2       486.0         0.0          GLQ   ...         WD            0    Pave
# 3       216.0         0.0          ALQ   ...         WD            0    Pave
# 4       655.0         0.0          GLQ   ...         WD            0    Pave
#
#   TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0            8        856.0    AllPub          0      2003         2003
# 1            6       1262.0    AllPub        298      1976         1976
# 2            6        920.0    AllPub          0      2001         2002
# 3            7        756.0    AllPub          0      1915         1970
# 4            9       1145.0    AllPub        192      2000         2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
#
# [5 rows x 76 columns]

# %%
# preparing the dataframe for processing
lotFr = bothdf[['LotArea','1stFlrSF','GrLivArea','GarageArea','LotFrontage']]
lotFr_nn = lotFr[lotFr['LotFrontage'].notnull() & lotFr['GarageArea'].notnull()]
lotFr.count()
lotFr_nn.isnull().sum()
# Out:
# LotArea        0
# 1stFlrSF       0
# GrLivArea      0
# GarageArea     0
# LotFrontage    0
# dtype: int64

# %%
lotFr_nn.head()
# Out:
#    LotArea  1stFlrSF  GrLivArea  GarageArea  LotFrontage
# 0     8450       856       1710       548.0         65.0
# 1     9600      1262       1262       460.0         80.0
# 2    11250       920       1786       608.0         68.0
# 3     9550       961       1717       642.0         60.0
# 4    14260      1145       2198       836.0         84.0

# %%
X_lot = lotFr_nn.iloc[:, :-1].values
y_lot = lotFr_nn.iloc[:, 4:].values
y_lot
# Out:
# array([[  65.],
#        [  80.],
#        [  68.],
#        ...,
#        [ 160.],
#        [  62.],
#        [  74.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_lot, y_lot, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_lotfr_X = StandardScaler()
sc_lotfr_Y = StandardScaler()

X_lot_train = sc_lotfr_X.fit_transform(X_train)
X_lot_test = sc_lotfr_X.transform(X_test)

y_lot_train = sc_lotfr_Y.fit_transform(y_train)
y_lot_test = sc_lotfr_Y.transform(y_test)
y_lot_test
# Out:
# array([[ 3.12745773],
#        [-0.40620463],
#        [ 0.14067169],
#        [-1.6682269 ],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [ 0.43514355],
#        [ 1.40269396],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.78481131],
#        [ 1.40269396],
#        [ 2.11783991],
#        [-0.40620463],
#        [ 0.60341319],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.15380018],
#        [ 3.37986218],
#        [ 0.2248065 ],
#        [-0.61654168],
#        [-0.02759795],
#        [-0.19586759],
#        [-1.92063136],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.43514355],
#        [-1.16341799],
#        [-0.82687872],
#        [ 0.35100873],
#        [-0.06966536],
#        [ 0.14067169],
#        [-1.2054854 ],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.39307614],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.61654168],
#        [-0.86894613],
#        [ 0.18273909],
#        [ 0.01446946],
#        [-0.06966536],
#        [-0.02759795],
#        [-0.32206981],
#        [ 0.43514355],
#        [-0.82687872],
#        [-1.12135059],
#        [ 0.2248065 ],
#        [-0.7427439 ],
#        [-0.82687872],
#        [-0.82687872],
#        [ 0.64548059],
#        [-0.7427439 ],
#        [-0.11173277],
#        [ 0.01446946],
#        [-1.92063136],
#        [ 0.43514355],
#        [ 0.43514355],
#        [-1.45788986],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.09860428],
#        [-0.11173277],
#        [-1.07928318],
#        [ 0.64548059],
#        [-1.24755281],
#        [ 0.35100873],
#        [ 1.06615468],
#        [-0.40620463],
#        [-0.2800024 ],
#        [-2.04683358],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.36413722],
#        [-0.53240686],
#        [-0.95308095],
#        [-1.12135059],
#        [-0.7006765 ],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 2.95918809],
#        [-0.19586759],
#        [-0.11173277],
#        [ 0.18273909],
#        [ 0.64548059],
#        [-0.15380018],
#        [-0.19586759],
#        [-1.07928318],
#        [ 1.19235691],
#        [ 0.85581764],
#        [ 0.01446946],
#        [-0.11173277],
#        [-1.2054854 ],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.19586759],
#        [ 0.43514355],
#        [-0.237935  ],
#        [-0.40620463],
#        [-0.15380018],
#        [ 0.2248065 ],
#        [ 0.30894132],
#        [-0.19586759],
#        [ 1.06615468],
#        [ 0.43514355],
#        [ 0.64548059],
#        [-0.32206981],
#        [-0.2800024 ],
#        [ 0.43514355],
#        [ 1.57096359],
#        [ 0.35100873],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.89788505],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.77168282],
#        [ 0.60341319],
#        [ 0.05653687],
#        [ 0.14067169],
#        [-0.40620463],
#        [-0.32206981],
#        [ 0.2248065 ],
#        [ 0.01446946],
#        [-1.58409209],
#        [ 0.64548059],
#        [-0.19586759],
#        [ 0.64548059],
#        [-1.92063136],
#        [ 1.69716582],
#        [-2.04683358],
#        [-0.15380018],
#        [-0.40620463],
#        [-0.02759795],
#        [ 1.06615468],
#        [-0.15380018],
#        [-0.19586759],
#        [ 1.19235691],
#        [ 1.69716582],
#        [-0.53240686],
#        [ 0.39307614],
#        [-1.2054854 ],
#        [-0.2800024 ],
#        [ 0.85581764],
#        [-0.40620463],
#        [-0.78481131],
#        [ 3.463997  ],
#        [-0.7006765 ],
#        [-0.49033945],
#        [ 0.72961541],
#        [ 1.86543546],
#        [-1.24755281],
#        [-1.24755281],
#        [-0.61654168],
#        [-2.04683358],
#        [-0.40620463],
#        [ 0.85581764],
#        [-0.53240686],
#        [-0.95308095],
#        [-0.65860909],
#        [ 1.19235691],
#        [ 0.43514355],
#        [-0.82687872],
#        [-0.53240686],
#        [ 0.77168282],
#        [ 0.77168282],
#        [ 2.32817696],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [-1.6682269 ],
#        [-1.92063136],
#        [ 1.06615468],
#        [ 0.01446946],
#        [-2.04683358],
#        [ 0.43514355],
#        [ 2.49644659],
#        [-0.40620463],
#        [ 1.44476137],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 0.01446946],
#        [ 0.43514355],
#        [ 0.39307614],
#        [ 0.01446946],
#        [ 2.70678364],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-0.40620463],
#        [-0.11173277],
#        [ 0.56134578],
#        [-0.40620463],
#        [ 0.64548059],
#        [-1.58409209],
#        [ 2.11783991],
#        [ 0.09860428],
#        [-0.2800024 ],
#        [-0.82687872],
#        [-0.7427439 ],
#        [ 0.64548059],
#        [ 0.01446946],
#        [-0.7006765 ],
#        [-0.61654168],
#        [-0.82687872],
#        [-1.37375504],
#        [-2.04683358],
#        [ 0.26687391],
#        [-0.40620463],
#        [-1.2054854 ],
#        [-0.06966536],
#        [-0.15380018],
#        [-1.54202468],
#        [-0.237935  ],
#        [ 0.01446946],
#        [-0.49033945],
#        [-0.82687872],
#        [-0.40620463],
#        [ 0.14067169],
#        [ 0.2248065 ],
#        [ 0.64548059],
#        [-0.57447427],
#        [ 0.93995246],
#        [-0.19586759],
#        [-0.2800024 ],
#        [-0.40620463],
#        [-1.49995727],
#        [ 1.27649173],
#        [ 0.09860428],
#        [ 0.43514355],
#        [ 0.39307614],
#        [-0.7006765 ],
#        [ 1.02408728],
#        [ 0.39307614],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [-1.28962022],
#        [-0.40620463],
#        [-0.82687872],
#        [-0.44827204],
#        [-0.2800024 ],
#        [-1.37375504],
#        [ 0.60341319],
#        [-0.40620463],
#        [-0.40620463],
#        [-1.49995727],
#        [-0.82687872],
#        [-0.82687872],
#        [-2.04683358],
#        [-0.237935  ],
#        [-0.19586759],
#        [-0.36413722],
#        [ 2.03370509],
#        [-2.04683358],
#        [-1.45788986],
#        [ 0.98201987],
#        [ 0.93995246],
#        [ 0.687548  ],
#        [ 0.98201987],
#        [-0.2800024 ],
#        [ 1.86543546],
#        [-0.49033945],
#        [-0.40620463],
#        [ 0.01446946],
#        [-2.04683358],
#        [-0.78481131],
#        [ 0.98201987],
#        [ 0.01446946],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [ 0.2248065 ],
#        [-0.82687872],
#        [-0.44827204],
#        [ 0.51927837],
#        [-1.92063136],
#        [-0.40620463],
#        [-2.04683358],
#        [ 0.43514355],
#        [-0.19586759],
#        [ 0.47721096],
#        [ 2.28610955],
#        [-1.92063136],
#        [-2.04683358],
#        [-1.2054854 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 1.10822209],
#        [ 0.01446946],
#        [-1.24755281],
#        [-1.92063136],
#        [-1.92063136],
#        [-0.2800024 ],
#        [-0.02759795],
#        [ 0.64548059],
#        [ 0.85581764],
#        [-0.237935  ],
#        [-0.40620463],
#        [ 0.43514355],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [-0.53240686],
#        [-0.11173277],
#        [-0.40620463],
#        [-0.82687872],
#        [ 0.43514355],
#        [ 0.05653687],
#        [-0.40620463],
#        [ 0.35100873],
#        [ 1.02408728],
#        [-0.19586759],
#        [ 0.14067169],
#        [ 0.05653687],
#        [-0.7427439 ],
#        [ 0.35100873],
#        [-0.40620463],
#        [ 0.43514355],
#        [-0.36413722],
#        [-0.19586759],
#        [-0.15380018],
#        [ 0.64548059],
#        [-0.82687872],
#        [-0.19586759],
#        [ 0.47721096],
#        [-0.82687872],
#        [-0.61654168],
#        [ 0.14067169],
#        [ 1.36062655],
#        [-0.44827204],
#        [-0.40620463],
#        [-1.92063136],
#        [-0.7427439 ],
#        [ 0.2248065 ],
#        [-1.16341799],
#        [-1.58409209],
#        [-0.19586759],
#        [ 0.60341319],
#        [ 0.09860428],
#        [ 1.19235691],
#        [-0.06966536],
#        [-0.19586759],
#        [-0.40620463],
#        [ 0.05653687],
#        [ 0.35100873],
#        [ 0.81375023],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.687548  ],
#        [-0.82687872],
#        [-0.40620463],
#        [-0.06966536],
#        [-0.36413722],
#        [ 1.613031  ],
#        [ 0.64548059],
#        [-0.40620463],
#        [ 0.01446946],
#        [-0.237935  ],
#        [-0.19586759],
#        [ 0.51927837],
#        [ 0.35100873],
#        [ 0.09860428],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 1.65509841],
#        [ 0.05653687],
#        [ 0.687548  ],
#        [ 0.43514355],
#        [ 0.01446946],
#        [ 0.01446946],
#        [-0.40620463],
#        [-1.28962022],
#        [-1.41582245],
#        [ 0.43514355],
#        [ 0.01446946],
#        [-0.40620463],
#        [ 0.39307614],
#        [ 0.64548059],
#        [ 0.2248065 ],
#        [ 0.43514355],
#        [-0.61654168],
#        [-0.19586759],
#        [-0.40620463],
#        [-1.07928318],
#        [-0.61654168],
#        [ 0.43514355],
#        [-0.78481131],
#        [-0.49033945],
#        [-1.41582245],
#        [-0.237935  ],
#        [ 0.85581764],
#        [-0.82687872],
#        [-0.78481131],
#        [ 3.59019923],
#        [ 0.01446946],
#        [ 0.01446946],
#        [ 0.43514355],
#        [-0.02759795],
#        [-1.45788986],
#        [-0.86894613],
#        [-0.65860909],
#        [ 0.2248065 ],
#        [ 1.06615468],
#        [ 0.14067169],
#        [ 0.60341319],
#        [-0.06966536],
#        [-0.2800024 ],
#        [-0.06966536],
#        [-0.40620463],
#        [ 0.98201987],
#        [-0.06966536],
#        [ 0.09860428],
#        [-0.40620463],
#        [ 1.27649173],
#        [ 0.30894132],
#        [-0.02759795],
#        [ 0.43514355],
#        [-0.237935  ],
#        [ 0.14067169],
#        [-1.54202468],
#        [ 0.89788505],
#        [-1.58409209],
#        [-0.40620463],
#        [ 0.26687391],
#        [ 0.01446946],
#        [ 0.39307614],
#        [ 0.47721096],
#        [-0.40620463],
#        [ 0.18273909],
#        [ 0.85581764],
#        [-1.92063136],
#        [-0.19586759],
#        [-1.16341799],
#        [ 0.72961541],
#        [-0.19586759],
#        [ 0.2248065 ],
#        [-0.40620463],
#        [ 0.2248065 ],
#        [ 2.49644659],
#        [ 0.43514355],
#        [-0.82687872],
#        [ 0.51927837],
#        [ 1.69716582],
#        [-0.49033945],
#        [ 1.78130064],
#        [-0.44827204],
#        [ 1.78130064],
#        [ 0.60341319],
#        [-1.92063136],
#        [-0.82687872],
#        [-0.11173277],
#        [ 0.93995246],
#        [-0.40620463],
#        [-0.40620463],
#        [ 0.98201987],
#        [ 0.09860428],
#        [-1.87856395],
#        [-0.02759795],
#        [-0.7427439 ],
#        [-1.45788986],
#        [ 0.60341319],
#        [-0.53240686],
#        [-0.57447427],
#        [ 0.2248065 ],
#        [ 0.18273909],
#        [ 1.19235691],
#        [ 0.01446946],
#        [ 0.18273909]])

# %%
from sklearn.tree import DecisionTreeRegressor
lot_reg = DecisionTreeRegressor()
lot_reg.fit(X_lot_train,y_lot_train.ravel())
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
fr_preds = lot_reg.predict(X_lot_test)
fr_preds
# Out:
# array([  1.27649173,  -0.40620463,   0.64548059,  -1.6682269 ,
#         -0.49033945,  -0.82687872,  -0.82687872,  -0.2800024 ,
#          0.01446946,   1.44476137,   1.78130064,  -0.40620463,
#          1.613031  ,  -0.78481131,   1.27649173,  -1.16341799,
#         -0.32206981,  -0.40620463,   0.39307614,  -0.19586759,
#          0.2248065 ,   3.80053627,   1.73923323,  -0.49033945,
#         -0.7006765 ,  -0.15380018,  -0.91101354,  -1.92063136,
#          2.70678364,  -0.06966536,  -0.61654168,  -0.11173277,
#         -0.237935  ,  -1.45788986,  -0.82687872,  -1.03721577,
#         -0.02759795,   0.14067169,   0.39307614,  -0.02759795,
#         -0.53240686,   0.14067169,   0.43514355,  -0.40620463,
#          0.64548059,  -0.2800024 ,   0.2248065 ,   0.01446946,
#          0.35100873,   0.93995246,  -0.2800024 ,   0.43514355,
#         -0.237935  ,  -0.32206981,  -1.49995727,   1.10822209,
#         -1.07928318,   0.01446946,  -0.57447427,  -0.82687872,
#          0.43514355,  -0.19586759,  -0.40620463,   0.01446946,
#          0.35100873,  -1.92063136,   0.26687391,   0.64548059,
#          0.64548059,  -0.91101354,   0.93995246,  -0.82687872,
#          0.43514355,   0.01446946,   0.43514355,  -0.82687872,
#         -0.40620463,   1.31855914,  -0.65860909,   1.19235691,
#         -1.12135059,   0.72961541,   2.538514  ,  -1.92063136,
#         -0.61654168,   4.38948   ,  -0.91101354,   0.2248065 ,
#          1.57096359,   1.10822209,  -1.16341799,  -1.12135059,
#         -1.33168763,  -0.7427439 ,  -1.45788986,   0.01446946,
#         -0.237935  ,  10.23684986,  -0.32206981,   0.43514355,
#          0.64548059,   2.45437918,   0.2248065 ])

# %%
from sklearn.model_selection import cross_val_score
cross_score = cross_val_score(lot_reg,X_lot_train,y_lot_train,cv=5,n_jobs=-1)
print(cross_score)
print("Accuracy: %0.2f (+/- %0.2f)" % (cross_score.mean(), cross_score.std() * 2))
# Out:
# [ 0.16057606  0.13753939  0.03744439  0.09481367 -0.14428612]
# Accuracy: 0.06 (+/- 0.22)

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_lot_test, fr_preds)))
# Out:
# RMSE: 1.01206949249

# %%
# without transforming
from sklearn.ensemble import RandomForestRegressor
rreg = RandomForestRegressor(n_estimators=150)
rreg.fit(X_train,y_train.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=150, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
new_preds = rreg.predict(X_test)
new_preds
# Out:
# array([  96.08      ,   60.4       ,   92.39333333,   31.08      ,
#          65.81333333,   65.68      ,   66.24666667,   72.12      ,
#          83.04      ,  101.62      ,  110.00666667,   60.03333333,
#          98.29333333,   54.12      ,   87.54666667,   81.29333333,
#          62.63333333,   66.72      ,   59.82      ,   65.05333333,
#          61.20666667,  110.72      ,  107.29333333,   71.19333333,
#          52.84666667,   72.73333333,   43.1       ,   24.        ,
#          63.78      ,   84.23333333,   68.32      ,   52.62      ,
#          75.86      ,   65.85333333,   72.7       ,  110.06      ,
#          70.67333333,   77.27333333,   74.92      ,   68.65333333,
#          45.04666667,   78.65333333,   67.42      ,   69.70666667,
#          66.48666667,   60.13333333,   79.13333333,   66.48      ,
#          66.45333333,   74.27333333,   65.44666667,   76.23333333,
#          69.95333333,   80.47333333,   69.30666667,   61.92      ,
#          76.96      ,   63.51333333,   93.36      ,   59.34      ,
#          39.92      ,   78.00666667,   53.32666667,   58.00666667,
#          70.42      ,   71.41333333,   56.56666667,   81.5       ,
#          66.86666667,   24.        ,   73.40666667,   80.17333333,
#          37.18      ,   71.17333333,   72.82666667,   70.93333333,
#          82.04      ,   59.12      ,   69.98      ,   43.96      ,
#          97.12666667,   60.32      ,   77.68      ,   89.54      ,
#          61.3       ,   64.30666667,   21.        ,   83.55333333,
#          63.5       ,   75.66666667,  101.80666667,   69.55333333,
#         100.88      ,   24.        ,   24.        ,   90.73333333,
#          67.92666667,   79.97333333,   81.22      ,   72.88      ,
#          72.50666667,   77.72      ,   79.58666667,   54.64666667,
#          64.92      ,   71.18      ,   62.52      ,   57.14666667,
#          71.85333333,   66.74      ,   64.19333333,   79.1       ,
#          89.86666667,   67.07333333,   90.54      ,   74.21333333,
#          56.21333333,   75.55333333,   63.17333333,   69.56666667,
#          71.64666667,   61.76      ,   62.28666667,   78.12666667,
#          69.17333333,   65.12666667,   56.26666667,   27.12666667,
#          64.67333333,   65.85333333,   84.02666667,   75.89333333,
#          66.16666667,   23.66      ,   56.45333333,   78.72      ,
#          41.98666667,   35.70666667,   66.08      ,   81.48      ,
#          63.98      ,   72.64      ,   73.62      ,   63.46666667,
#          63.66      ,   66.74666667,   86.65333333,   76.86666667,
#          98.80666667,   78.66666667,   62.41333333,   89.65333333,
#          58.02      ,   77.10666667,   69.23333333,   68.12666667,
#          99.56666667,  101.76666667,  101.16666667,   67.69333333,
#          65.98666667,   72.64      ,   79.50666667,   69.17333333,
#          61.77333333,   68.00666667,   58.33333333,   95.26666667,
#          63.65333333,   90.49333333,   80.6       ,   69.41333333,
#          91.08      ,   60.62      ,   45.00666667,   25.54      ,
#          77.98      ,   68.02666667,   54.64      ,   67.53333333,
#          99.84      ,   66.06      ,   80.44666667,   74.84666667,
#          66.77333333,   62.62666667,   74.49333333,   51.54      ,
#          77.96666667,   64.04666667,   79.71333333,   49.49333333,
#          75.15333333,   82.55333333,   60.24      ,   56.23333333,
#         106.56666667,   70.84      ,   64.74666667,   68.22666667,
#          74.1       ,   40.4       ,   98.11333333,   52.50666667,
#          63.42666667,   89.33333333,   79.02666667,   66.90666667,
#          69.1       ,   76.88666667,   69.26      ,   62.94666667,
#         103.04666667,   57.64      ,   69.58666667,   59.96      ,
#          70.91333333,   79.42666667,   52.42      ,   69.48      ,
#          63.43333333,   68.85333333,   37.96666667,   78.92      ,
#          44.21333333,   71.63333333,   71.94      ,   53.36666667,
#          72.76      ,   64.85333333,   60.18      ,   77.77333333,
#          76.72666667,   25.15333333,   66.21333333,   98.12      ,
#          91.97333333,   64.65333333,   90.63333333,   72.94      ,
#          76.54666667,   73.82666667,   79.54      ,   60.30666667,
#          66.42666667,   94.31333333,   57.86      ,   92.44666667,
#          49.80666667,   92.74      ,   71.42      ,   28.91333333,
#          55.26      ,  108.74666667,   54.69333333,   77.04666667,
#          85.10666667,   93.68666667,   77.2       ,   40.78666667,
#          63.65333333,   60.65333333,   35.        ,   78.88666667,
#          65.95333333,  183.24666667,   65.69333333,   81.02666667,
#          89.48      ,   97.82      ,   81.14      ])

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(new_preds, y_test)))
# Out:
# RMSE: 16.725747268

# %%
from sklearn.model_selection import cross_val_score
cross_score = cross_val_score(rreg,X_train,y_train,cv=5,n_jobs=-1)
print(cross_score)
print(np.mean(cross_score))
np.var(cross_score)
# Out:
# [ 0.55683814  0.38922152  0.49434282  0.54520571  0.41489808]
# 0.480101252414
# 0.0045681085858542752
