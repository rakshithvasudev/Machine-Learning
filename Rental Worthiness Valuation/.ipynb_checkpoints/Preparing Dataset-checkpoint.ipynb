# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
ficoscores = np.random.randint(350,850,500)
ficoscores
# Out:
# array([482, 686, 471, 768, 800, 830, 368, 819, 688, 560, 411, 684, 829,
#        617, 558, 534, 487, 833, 738, 846, 503, 404, 715, 785, 426, 385,
#        506, 370, 839, 829, 363, 572, 367, 357, 755, 597, 556, 818, 489,
#        790, 593, 676, 521, 604, 599, 633, 659, 402, 804, 574, 600, 525,
#        676, 484, 780, 793, 738, 506, 606, 428, 765, 365, 739, 835, 744,
#        679, 564, 739, 360, 808, 827, 510, 846, 499, 502, 585, 670, 559,
#        558, 566, 655, 461, 441, 819, 461, 446, 370, 655, 477, 689, 827,
#        568, 421, 569, 472, 358, 818, 667, 557, 364, 557, 416, 565, 662,
#        705, 647, 822, 514, 835, 842, 359, 464, 540, 792, 613, 625, 438,
#        399, 622, 816, 802, 815, 548, 422, 775, 437, 467, 507, 732, 678,
#        361, 783, 362, 639, 695, 563, 586, 775, 597, 567, 495, 469, 668,
#        418, 763, 656, 619, 798, 672, 392, 603, 779, 419, 740, 356, 641,
#        511, 531, 546, 374, 799, 547, 435, 762, 555, 834, 635, 409, 718,
# ...

# %%
length_of_employment = np.random.uniform(low=0.0, high=5, size=500)
length_of_employment
# Out:
# array([ 1.33950148,  2.41166966,  3.42382162,  4.81382048,  2.36340719,
#         3.80348149,  2.78811865,  0.00660748,  0.79377043,  0.75770903,
#         2.84666118,  4.70166444,  2.86694188,  1.59138226,  4.2479103 ,
#         1.24990357,  0.80206165,  1.94462954,  3.73162795,  4.37414927,
#         0.45710256,  2.43496561,  1.30427143,  0.11593412,  4.01433156,
#         4.12988526,  0.36298152,  1.35771719,  0.3716985 ,  1.28343449,
#         0.14232083,  4.22905059,  0.44740463,  4.92524127,  2.60850191,
#         2.26039893,  3.42739347,  0.53649617,  3.18536708,  4.10899303,
#         2.78270414,  4.68437747,  4.67388158,  4.46999633,  4.82781356,
#         1.02690573,  3.10759047,  0.70336368,  2.85047078,  0.13957367,
#         2.15077244,  2.97403653,  3.23818375,  4.32060345,  0.415461  ,
#         3.00085708,  0.55752942,  1.63008272,  4.63547143,  0.07602023,
#         0.90434713,  2.17238848,  3.89650614,  4.71549286,  0.96545862,
# ...

# %%
length_of_current_residency = np.random.uniform(low=0.0, high=3, size=500)
length_of_current_residency
# Out:
# array([  7.56560936e-01,   9.77482710e-01,   1.67976140e+00,
#          3.38533177e-01,   8.78235814e-02,   1.08093515e+00,
#          1.75979454e+00,   2.80202284e+00,   1.11328769e+00,
#          1.52054553e+00,   1.39553293e+00,   1.27539309e+00,
#          1.90158775e+00,   2.30382158e+00,   6.00005321e-01,
#          2.36779635e+00,   7.20209306e-01,   1.77879561e+00,
#          2.73569666e+00,   1.68133320e+00,   1.99571089e+00,
#          2.69868873e-01,   2.38913531e+00,   8.60078061e-01,
#          2.26478997e+00,   1.90911074e+00,   1.61304213e+00,
#          4.53293034e-01,   2.61534743e+00,   1.78731977e+00,
#          2.80456580e+00,   1.69539414e+00,   2.50643111e+00,
#          2.12797963e+00,   2.09887901e+00,   1.31427549e+00,
#          1.39976151e+00,   1.59035381e+00,   2.62749741e+00,
#          6.03379147e-02,   4.88731534e-01,   1.25616150e+00,
#          1.15914742e+00,   2.91976447e+00,   1.31782454e+00,
# ...

# %%
total_monthly_income = np.random.randint(2000,10000,500)
total_monthly_income
