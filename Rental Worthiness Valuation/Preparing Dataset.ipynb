# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
ficoscores = np.random.randint(350,850,250)
ficoscores
# Out:
# array([659, 462, 840, 583, 609, 642, 418, 733, 393, 504, 757, 701, 611,
#        418, 674, 559, 844, 842, 529, 519, 392, 476, 676, 590, 704, 544,
#        373, 460, 458, 762, 460, 692, 376, 628, 820, 619, 359, 719, 404,
#        415, 506, 807, 627, 388, 487, 628, 593, 629, 587, 407, 710, 588,
#        679, 680, 778, 707, 362, 646, 503, 683, 464, 790, 461, 723, 367,
#        394, 450, 754, 713, 519, 612, 360, 508, 443, 476, 578, 518, 661,
#        554, 669, 424, 459, 705, 646, 474, 747, 721, 640, 432, 537, 770,
#        537, 834, 350, 639, 798, 514, 350, 471, 637, 798, 656, 503, 822,
#        716, 708, 568, 826, 432, 699, 359, 643, 466, 410, 372, 832, 410,
#        573, 559, 751, 524, 730, 777, 595, 733, 652, 620, 649, 672, 442,
#        516, 836, 567, 753, 794, 400, 779, 475, 612, 480, 822, 675, 368,
#        510, 584, 633, 409, 465, 582, 506, 386, 448, 359, 379, 646, 390,
#        662, 697, 571, 638, 474, 735, 451, 505, 537, 502, 554, 457, 524,
# ...

# %%
length_of_employment = np.random.randint(low=0, high=60, size = 250)
length_of_employment
# Out:
# array([18, 22, 32,  1,  7, 19, 41, 42,  0, 58, 49, 18,  6, 56, 59,  7,  5,
#        22,  2, 25, 22,  5, 16, 12,  1, 49, 34, 28, 26,  8,  5, 34, 38, 20,
#        55, 56, 49, 26, 29,  5, 32, 18, 17, 20, 10, 48, 43,  9, 59, 27, 49,
#         6, 16, 23, 10,  8, 23, 45,  0, 49, 34, 41,  7, 36, 25, 29, 14, 16,
#        32, 12, 37, 21, 27, 22, 48, 53, 35, 53,  9, 47, 10,  6, 20, 57, 28,
#        35, 56,  3, 34,  5, 21, 52, 32, 37,  9,  6, 30,  6, 38, 46, 34,  4,
#        59, 32, 20, 32, 58, 21, 22, 26, 41, 39, 24, 37, 34, 20,  2, 48, 50,
#        51, 14, 34, 27, 11, 59, 46, 12, 53, 22, 29, 50,  3, 57, 47, 16,  8,
#        25,  6, 14, 11, 20, 38, 51, 59, 16, 32, 26, 32, 59, 19, 16, 32, 20,
#        48, 52, 27, 32, 14, 23, 17, 57, 40, 39, 56, 26, 54,  2,  7, 28, 44,
#        33,  9,  4, 11, 11,  8, 13, 32,  4, 52, 18, 26, 48, 18, 27, 37, 52,
#        40, 27, 30, 11,  7, 47, 21,  0,  0, 55, 33, 16, 12, 26, 20,  8, 50,
# ...

# %%
length_of_current_residency = np.random.randint(low=0, high=36, size=250)
length_of_current_residency
# Out:
# array([20, 26, 22, 34, 30, 32, 22, 35,  0, 11, 13, 15, 20, 18, 14, 15,  7,
#        12, 24,  3,  0, 27, 19,  4, 22, 35, 35, 16, 19,  4, 16, 16,  5, 28,
#        18,  3,  0, 18, 18,  4,  4, 35,  5,  5, 15,  4,  0, 22, 10,  4,  4,
#        34, 32,  3, 18, 18, 15, 17,  0, 34, 15, 30, 13, 22,  3, 20, 28, 23,
#         0, 15, 15, 13, 34, 19, 16,  4, 26, 31, 15, 19, 26, 28,  8, 29, 16,
#        32, 33,  8, 10, 15,  5,  4, 30, 14, 34,  9,  7, 13, 34, 27, 16, 12,
#        29, 35,  0, 20, 17, 22, 19, 10, 15, 21, 26, 24, 19,  1, 32,  5, 18,
#        32,  9, 35, 28,  7, 26,  7,  6,  2, 35,  5,  1, 22, 19,  5, 25, 13,
#         3, 27,  5, 13, 14, 13, 34, 27, 24, 32, 34, 11,  7, 25, 25, 34,  0,
#         0,  5, 23,  6,  0, 24, 20, 24,  3, 19, 16, 12, 12, 22, 19,  2, 18,
#         3,  8, 34,  8, 25, 28, 12,  3, 34, 21, 11, 32,  6, 21, 18, 23, 25,
#        33, 21, 15, 27,  0, 30, 28, 18, 20, 25, 11, 32,  5, 24, 22,  8,  1,
# ...

# %%
total_monthly_income = np.random.randint(2000,10000,250)
total_monthly_income
# Out:
# array([2819, 3103, 7440, 4570, 6256, 9377, 4160, 2791, 8472, 5448, 8227,
#        4249, 7978, 7530, 5419, 7943, 8379, 9228, 3574, 2033, 5996, 4737,
#        2613, 2764, 6634, 5163, 4079, 8366, 2336, 3890, 5317, 7058, 9964,
#        3600, 9184, 9037, 6125, 4716, 7818, 6562, 6196, 3096, 6613, 4850,
#        2823, 8142, 4408, 5459, 2696, 9616, 2771, 3452, 7019, 3836, 6119,
#        7213, 8605, 9824, 6451, 5254, 3106, 7879, 2577, 6556, 5793, 4016,
#        4854, 6515, 9069, 8172, 3932, 4964, 7504, 7356, 4178, 3066, 7380,
#        5619, 3588, 5679, 8519, 7721, 9547, 6667, 7433, 3880, 5335, 8931,
#        7764, 8378, 9728, 7835, 8965, 4902, 7614, 4185, 4216, 6824, 5737,
#        7929, 3871, 3312, 9574, 7885, 2417, 3679, 2498, 8094, 8563, 8583,
#        7190, 7700, 9824, 5118, 9185, 7118, 5617, 7432, 9717, 2617, 8957,
#        8446, 8376, 5265, 7431, 4321, 7911, 5853, 4695, 4777, 6785, 8174,
#        5348, 6851, 9837, 4590, 3441, 5518, 7976, 3179, 6819, 6399, 7176,
# ...

# %%
debt_to_income_ratio = np.random.uniform(low=0.0, high=1, size=250)
debt_to_income_ratio = debt_to_income_ratio * 100

# %%
main = pd.DataFrame(data=[ficoscores,length_of_employment,length_of_current_residency,total_monthly_income,debt_to_income_ratio]).T
main
# Out:
#           0      1      2        3      4
# 0   659.000 18.000 20.000 2819.000 55.049
# 1   462.000 22.000 26.000 3103.000 46.777
# 2   840.000 32.000 22.000 7440.000 45.944
# 3   583.000  1.000 34.000 4570.000 70.460
# 4   609.000  7.000 30.000 6256.000 18.644
# 5   642.000 19.000 32.000 9377.000 95.537
# 6   418.000 41.000 22.000 4160.000  3.656
# 7   733.000 42.000 35.000 2791.000 40.004
# 8   393.000  0.000  0.000 8472.000 70.733
# 9   504.000 58.000 11.000 5448.000  4.860
# 10  757.000 49.000 13.000 8227.000 90.100
# 11  701.000 18.000 15.000 4249.000 78.373
# 12  611.000  6.000 20.000 7978.000 51.372
# 13  418.000 56.000 18.000 7530.000 62.358
# 14  674.000 59.000 14.000 5419.000 75.976
# 15  559.000  7.000 15.000 7943.000 19.504
# 16  844.000  5.000  7.000 8379.000  7.764
# 17  842.000 22.000 12.000 9228.000 63.138
# 18  529.000  2.000 24.000 3574.000 63.913
# 19  519.000 25.000  3.000 2033.000 78.661
# 20  392.000 22.000  0.000 5996.000 64.762
# ...

# %%
main.to_csv("dataset2.csv")
